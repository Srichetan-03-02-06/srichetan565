# %%
model_influence = model.get_influence()
(c, _) = model.influence.cooks_distance
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-32bc72e9ad4e> in <cell line: 0>()
# ----> 1 model_influence = model.get_influence()
#       2 (c, _) = model.influence.cooks_distance
#
# NameError: name 'model' is not defined

# %%
fig = plt.subplot(figsize=(20,7))
plt.stem(np.arange(len(cars)), np.round(c, 3))
plt.xlabel('Row Index')
plt.ylabel('Cook\'s Distance')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-51201143edec> in <cell line: 0>()
# ----> 1 fig = plt.subplot(figsize=(20,7))
#       2 plt.stem(np.arange(len(cars)), np.round(c, 3))
#       3 plt.xlabel('Row Index')
#       4 plt.ylabel('Cook\'s Distance')
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

X = np.random.rand(100, 1)
Y = 2 * X + np.random.randn(100, 1)

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

influence = model.get_influence()
cooks_distance = influence.cooks_distance[0]


fig = plt.figure(figsize=(20,7))
plt.stem(np.arange(len(cooks_distance)), np.round(cooks_distance, 3))

plt.xlabel('Row Index')
plt.ylabel('Cook\'s Distance')
plt.title('Cook\'s Distance Plot')
plt.show()
