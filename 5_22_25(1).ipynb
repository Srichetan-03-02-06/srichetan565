# %%
def get_standardized_values( vals ):
  return ( vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual plot: ')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-556e2a57d1cc> in <cell line: 0>()
# ----> 1 plt.scatter(get_standardized_values(model.fittedvalues),
#       2             get_standardized_values(model.resid))
#       3
#       4 plt.title('Residual plot: ')
#       5 plt.xlabel('Standardized Fitted values')
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm

X = np.random.rand(100, 1)
Y = 2 * X + np.random.randn(100, 1)

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

def get_standardized_values(values):
    mean = np.mean(values)
    std = np.std(values)
    return (values - mean) / std

plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))
plt.title('Residual Plot')
plt.xlabel('Standardized Fitted Values')
plt.ylabel('Standardized Residual Values')

plt.show()
